# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Rifal Faturrohman**

# %% [markdown]
# Aspiring Data Scientist

# %% [markdown]
# I'm interested in data science because I love to transform complex data into actionable and clear insights.

# %% [markdown]
# ### Example: Python Function Arguments

# %%
# function with two arguments
def add_numbers(num1, num2):
    sum = num1 + num2
    print("Sum: ",sum)

# function call with two values
add_numbers(5, 4)

# Output: Sum: 9
# Out:
# Sum:  9

# %% [markdown]
# #### **Check data credibility using ROCCC method:**
# * Reliable
# * Original
# * Comprehensive
# * Current
# * Cited

# %% [markdown]
# |Column|Missing Value|Percentage|
# |:---:|:---:|:---:|
# |January|833064|14,70%|
# |February|833064|14,70%|
# |March|892742|15,75%|
# |April|892742|15,75%|

# %% [markdown]
# ![__results___53_0.png](attachment:__results___53_0.png)
# Source: https://www.kaggle.com/code/rifalfaturohman/bellabeat-case-study
